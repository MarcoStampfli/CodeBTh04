# %% [markdown]
# # SVM Training & Anwendung auf Punktwolken (Jupyter Notebook Style)
#
# ## Teil 1: Training
#
# #### Import der Funktionen

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
import joblib
import pickle
import os
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import time
from pathlib import Path

# %% [markdown]
# #### Training des SGDClassifier mit Abbruchschranke

# %%
start_time = time.time()
# 1. Daten einlesen (ohne Header)
input_datei = "PW_Klass_P3A1_gesamt_normalisiert.txt"

df = pd.read_csv(input_datei, sep=";", header=None, decimal=".")

# 1.1 Spaltennamen zuweisen
columns = [
    "X", "Y", "Z",
    "Red", "Green", "Blue",
    "Hue", "Saturation", "Value",
    "X_dir", "Y_dir", "Z_dir",
    "Label"
]
df.columns = columns

# 2. Label-Encoding
df["Label"] = df["Label"].astype("category")
df["LabelEncoded"] = df["Label"].cat.codes
label_mapping = dict(enumerate(df["Label"].cat.categories))

# Optional: Visualisierung der Label-Verteilung
df["Label"].value_counts().plot(kind='bar', title="Label Verteilung")
plt.tight_layout()
plt.savefig("label_verteilung.png")
plt.close()

# 3. Features & Ziel definieren
X = df[[
    "X", "Y", "Z",
    "Red", "Green", "Blue",
    "Hue", "Saturation", "Value",
    "X_dir", "Y_dir", "Z_dir"
]]
y = df["LabelEncoded"]

# 3.1 Train/Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 4. Skalierung (fit mit DataFrame!)
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 5. Modell trainieren mit SGDClassifier
# Parameterübersicht:
# - loss="hinge": klassischer SVM-Loss (lineare Trennung)
# - max_iter=1000: maximale Anzahl Trainingsdurchläufe (Epochen)
# - tol=1e-3: Abbruch, wenn sich das Ergebnis kaum noch verbessert
# - early_stopping=True: bricht ab, wenn sich der Score nicht verbessert
# - n_iter_no_change=5: Toleranz für Early Stopping (wie viele Epochen keine Verbesserung?)
# - verbose=1: zeigt Trainingsfortschritt im Terminal
from sklearn.linear_model import SGDClassifier

# Klassifikationsbericht & Confusion Matrix
model_name = "v3"
result_dir = f"Resultate_SGDClassifier_{model_name}"
os.makedirs(result_dir, exist_ok=True)

#model = SGDClassifier(loss="hinge", max_iter=1000, tol=1e-3, early_stopping=True, n_iter_no_change=5, verbose=1)
model = SGDClassifier(
    loss="hinge",
    penalty="l2",
    alpha=1e-5,
    max_iter=5000,
    tol=1e-4,
    early_stopping=False,
    verbose=1
)

model.fit(X_train_scaled, y_train)

# 6. Trainingsverlust & Score visualisieren
# Trainings- und Test-Score anzeigen und speichern
training_score = model.score(X_train_scaled, y_train)
test_score = model.score(X_test_scaled, y_test)

score_info = f"Trainings-Score: {training_score:.4f}"
f"Test-Score: {test_score:.4f}"

print("✅" + score_info)
with open(os.path.join(result_dir, "training_scores.txt"), "w") as f:
    f.write(score_info)

f"Test-Score: {test_score:.4f}"

print("✅" + score_info)
with open(os.path.join(result_dir, "training_scores.txt"), "w") as f:
    f.write(score_info)
    
# Aber wir können den Score pro Epoche über 'validation_scores_' visualisieren, falls vorhanden
if hasattr(model, "validation_scores_"):
    plt.plot(model.validation_scores_)
    plt.title("Validation Score pro Epoche")
    plt.xlabel("Epoche")
    plt.ylabel("Score")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(result_dir, "validation_score_plot.png"))
    plt.close()
    print("📈 Validation Score Verlauf gespeichert.")



# Klassifikationsbericht speichern
y_pred = model.predict(X_test_scaled)
report = classification_report(y_test, y_pred, target_names=df["Label"].cat.categories)
with open(os.path.join(result_dir, "klassifikationsbericht.txt"), "w", encoding="utf-8") as f:
    f.write(report)
print("📋 Klassifikationsbericht gespeichert.")

# Confusion Matrix speichern
disp = ConfusionMatrixDisplay.from_predictions(y_test, y_pred, display_labels=df["Label"].cat.categories, cmap="Blues", xticks_rotation=45)
disp.figure_.savefig(os.path.join(result_dir, "confusion_matrix.png"))
plt.close()
print("📊 Confusion Matrix gespeichert.")

# 7. Modell, Scaler, Mapping speichern
joblib.dump(model, os.path.join(result_dir, "sgd_model.pkl"))
joblib.dump(scaler, os.path.join(result_dir, "scaler.pkl"))
with open(os.path.join(result_dir, "label_mapping.pkl"), "wb") as f:
    pickle.dump(label_mapping, f)

print("✅ Training abgeschlossen und alles gespeichert.")

# 8. Zeit anzeigen
elapsed = time.time() - start_time
h, rem = divmod(elapsed, 3600)
m, s = divmod(rem, 60)
print(f"⏱️ Laufzeit: {int(h):02d}:{int(m):02d}:{s:05.2f} (Std:Min:Sek)")
# Out:
# -- Epoch 1
# Norm: 11.76, NNZs: 12, Bias: -2.180890, T: 1969499, Avg. loss: 0.305758
# Total training time: 0.54 seconds.
# -- Epoch 2
# Norm: 10.20, NNZs: 12, Bias: -2.123487, T: 3938998, Avg. loss: 0.173694
# Total training time: 1.06 seconds.
# -- Epoch 3
# Norm: 9.75, NNZs: 12, Bias: -2.010385, T: 5908497, Avg. loss: 0.167487
# Total training time: 1.58 seconds.
# -- Epoch 4
# Norm: 9.57, NNZs: 12, Bias: -2.005424, T: 7877996, Avg. loss: 0.164973
# Total training time: 2.10 seconds.
# -- Epoch 5
# Norm: 9.45, NNZs: 12, Bias: -1.864002, T: 9847495, Avg. loss: 0.163574
# Total training time: 2.62 seconds.
# -- Epoch 6
# Norm: 9.43, NNZs: 12, Bias: -1.911308, T: 11816994, Avg. loss: 0.162793
# Total training time: 3.14 seconds.
# -- Epoch 7
# Norm: 9.56, NNZs: 12, Bias: -1.906823, T: 13786493, Avg. loss: 0.162194
# Total training time: 3.66 seconds.
# -- Epoch 8
# Norm: 9.29, NNZs: 12, Bias: -1.947269, T: 15755992, Avg. loss: 0.161758
# Total training time: 4.19 seconds.
# -- Epoch 9
# Norm: 9.42, NNZs: 12, Bias: -1.943258, T: 17725491, Avg. loss: 0.161469
# Total training time: 4.74 seconds.
# -- Epoch 10
# Norm: 9.23, NNZs: 12, Bias: -1.848834, T: 19694990, Avg. loss: 0.161190
# Total training time: 5.25 seconds.
# -- Epoch 11
# Norm: 9.23, NNZs: 12, Bias: -1.955517, T: 21664489, Avg. loss: 0.160890
# Total training time: 5.77 seconds.
# -- Epoch 12
# Norm: 9.27, NNZs: 12, Bias: -1.836894, T: 23633988, Avg. loss: 0.160899
# Total training time: 6.30 seconds.
# -- Epoch 13
# Norm: 9.29, NNZs: 12, Bias: -1.923493, T: 25603487, Avg. loss: 0.160622
# Total training time: 6.82 seconds.
# -- Epoch 14
# Norm: 9.24, NNZs: 12, Bias: -1.903455, T: 27572986, Avg. loss: 0.160560
# Total training time: 7.35 seconds.
# -- Epoch 15
# Norm: 9.22, NNZs: 12, Bias: -1.906035, T: 29542485, Avg. loss: 0.160437
# Total training time: 7.86 seconds.
# -- Epoch 16
# Norm: 9.22, NNZs: 12, Bias: -1.851183, T: 31511984, Avg. loss: 0.160321
# Total training time: 8.40 seconds.
# -- Epoch 17
# Norm: 9.21, NNZs: 12, Bias: -1.889280, T: 33481483, Avg. loss: 0.160310
# Total training time: 8.95 seconds.
# -- Epoch 18
# Norm: 9.20, NNZs: 12, Bias: -1.894847, T: 35450982, Avg. loss: 0.160238
# Total training time: 9.50 seconds.
# -- Epoch 19
# Norm: 9.24, NNZs: 12, Bias: -1.899632, T: 37420481, Avg. loss: 0.160116
# Total training time: 10.06 seconds.
# -- Epoch 20
# Norm: 9.18, NNZs: 12, Bias: -1.817836, T: 39389980, Avg. loss: 0.160084
# Total training time: 10.62 seconds.
# -- Epoch 21
# Norm: 9.18, NNZs: 12, Bias: -1.857218, T: 41359479, Avg. loss: 0.160021
# Total training time: 11.12 seconds.
# -- Epoch 22
# Norm: 9.18, NNZs: 12, Bias: -1.918308, T: 43328978, Avg. loss: 0.159971
# Total training time: 11.61 seconds.
# -- Epoch 23
# Norm: 9.14, NNZs: 12, Bias: -1.881480, T: 45298477, Avg. loss: 0.159948
# Total training time: 12.11 seconds.
# -- Epoch 24
# Norm: 9.19, NNZs: 12, Bias: -1.913092, T: 47267976, Avg. loss: 0.159867
# Total training time: 12.60 seconds.
# Convergence after 24 epochs took 12.60 seconds
# -- Epoch 1
# Norm: 9.36, NNZs: 12, Bias: -4.384383, T: 1969499, Avg. loss: 0.326250
# Total training time: 0.50 seconds.
# -- Epoch 2
# Norm: 7.87, NNZs: 12, Bias: -3.580316, T: 3938998, Avg. loss: 0.140498
# Total training time: 0.99 seconds.
# -- Epoch 3
# Norm: 7.44, NNZs: 12, Bias: -3.403901, T: 5908497, Avg. loss: 0.131435
# Total training time: 1.49 seconds.
# -- Epoch 4
# Norm: 7.25, NNZs: 12, Bias: -3.372918, T: 7877996, Avg. loss: 0.127840
# Total training time: 1.99 seconds.
# -- Epoch 5
# Norm: 7.04, NNZs: 12, Bias: -3.136135, T: 9847495, Avg. loss: 0.125783
# Total training time: 2.48 seconds.
# -- Epoch 6
# Norm: 6.92, NNZs: 12, Bias: -3.258277, T: 11816994, Avg. loss: 0.124486
# Total training time: 2.97 seconds.
# -- Epoch 7
# Norm: 6.97, NNZs: 12, Bias: -3.282932, T: 13786493, Avg. loss: 0.123658
# Total training time: 3.46 seconds.
# -- Epoch 8
# Norm: 6.90, NNZs: 12, Bias: -3.114848, T: 15755992, Avg. loss: 0.123018
# Total training time: 3.95 seconds.
# -- Epoch 9
# Norm: 6.92, NNZs: 12, Bias: -3.168872, T: 17725491, Avg. loss: 0.122572
# Total training time: 4.43 seconds.
# -- Epoch 10
# Norm: 6.91, NNZs: 12, Bias: -3.221059, T: 19694990, Avg. loss: 0.122215
# Total training time: 4.91 seconds.
# -- Epoch 11
# Norm: 6.88, NNZs: 12, Bias: -3.170770, T: 21664489, Avg. loss: 0.121955
# Total training time: 5.40 seconds.
# -- Epoch 12
# Norm: 6.91, NNZs: 12, Bias: -3.161854, T: 23633988, Avg. loss: 0.121649
# Total training time: 5.88 seconds.
# -- Epoch 13
# Norm: 6.88, NNZs: 12, Bias: -3.079789, T: 25603487, Avg. loss: 0.121458
# Total training time: 6.37 seconds.
# -- Epoch 14
# Norm: 6.84, NNZs: 12, Bias: -3.081421, T: 27572986, Avg. loss: 0.121342
# Total training time: 6.85 seconds.
# -- Epoch 15
# Norm: 6.91, NNZs: 12, Bias: -3.096131, T: 29542485, Avg. loss: 0.121127
# Total training time: 7.34 seconds.
# -- Epoch 16
# Norm: 6.86, NNZs: 12, Bias: -3.165687, T: 31511984, Avg. loss: 0.120985
# Total training time: 7.83 seconds.
# -- Epoch 17
# Norm: 6.87, NNZs: 12, Bias: -3.122424, T: 33481483, Avg. loss: 0.120877
# Total training time: 8.31 seconds.
# -- Epoch 18
# Norm: 6.84, NNZs: 12, Bias: -3.098018, T: 35450982, Avg. loss: 0.120779
# Total training time: 8.81 seconds.
# -- Epoch 19
# Norm: 6.84, NNZs: 12, Bias: -3.118375, T: 37420481, Avg. loss: 0.120752
# Total training time: 9.30 seconds.
# -- Epoch 20
# Norm: 6.84, NNZs: 12, Bias: -3.025101, T: 39389980, Avg. loss: 0.120631
# Total training time: 9.78 seconds.
# -- Epoch 21
# Norm: 6.82, NNZs: 12, Bias: -3.112286, T: 41359479, Avg. loss: 0.120554
# Total training time: 10.27 seconds.
# -- Epoch 22
# Norm: 6.87, NNZs: 12, Bias: -3.020660, T: 43328978, Avg. loss: 0.120508
# Total training time: 10.75 seconds.
# -- Epoch 23
# Norm: 6.82, NNZs: 12, Bias: -3.106965, T: 45298477, Avg. loss: 0.120449
# Total training time: 11.23 seconds.
# -- Epoch 24
# Norm: 6.88, NNZs: 12, Bias: -3.044180, T: 47267976, Avg. loss: 0.120379
# Total training time: 11.74 seconds.
# -- Epoch 25
# Norm: 6.85, NNZs: 12, Bias: -2.978519, T: 49237475, Avg. loss: 0.120342
# Total training time: 12.23 seconds.
# Convergence after 25 epochs took 12.23 seconds
# -- Epoch 1
# Norm: 4.61, NNZs: 12, Bias: -3.131033, T: 1969499, Avg. loss: 0.023639
# Total training time: 0.51 seconds.
# -- Epoch 2
# Norm: 2.25, NNZs: 12, Bias: -1.994736, T: 3938998, Avg. loss: 0.010534
# Total training time: 1.01 seconds.
# -- Epoch 3
# Norm: 1.52, NNZs: 12, Bias: -1.693624, T: 5908497, Avg. loss: 0.009815
# Total training time: 1.50 seconds.
# -- Epoch 4
# Norm: 1.14, NNZs: 12, Bias: -1.470690, T: 7877996, Avg. loss: 0.009527
# Total training time: 2.00 seconds.
# -- Epoch 5
# Norm: 0.90, NNZs: 12, Bias: -1.384007, T: 9847495, Avg. loss: 0.009367
# Total training time: 2.49 seconds.
# -- Epoch 6
# Norm: 0.71, NNZs: 12, Bias: -1.303717, T: 11816994, Avg. loss: 0.009265
# Total training time: 2.99 seconds.
# -- Epoch 7
# Norm: 0.65, NNZs: 12, Bias: -1.288826, T: 13786493, Avg. loss: 0.009192
# Total training time: 3.48 seconds.
# -- Epoch 8
# Norm: 0.58, NNZs: 12, Bias: -1.254047, T: 15755992, Avg. loss: 0.009143
# Total training time: 3.98 seconds.
# -- Epoch 9
# Norm: 0.50, NNZs: 12, Bias: -1.223530, T: 17725491, Avg. loss: 0.009105
# Total training time: 4.48 seconds.
# -- Epoch 10
# Norm: 0.47, NNZs: 12, Bias: -1.191307, T: 19694990, Avg. loss: 0.009072
# Total training time: 4.98 seconds.
# -- Epoch 11
# Norm: 0.41, NNZs: 12, Bias: -1.190896, T: 21664489, Avg. loss: 0.009049
# Total training time: 5.47 seconds.
# Convergence after 11 epochs took 5.47 seconds
# -- Epoch 1
# Norm: 17.80, NNZs: 12, Bias: -2.824979, T: 1969499, Avg. loss: 0.335828
# Total training time: 0.50 seconds.
# -- Epoch 2
# Norm: 16.33, NNZs: 12, Bias: -2.545132, T: 3938998, Avg. loss: 0.188727
# Total training time: 1.00 seconds.
# -- Epoch 3
# Norm: 15.68, NNZs: 12, Bias: -2.429539, T: 5908497, Avg. loss: 0.181892
# Total training time: 1.51 seconds.
# -- Epoch 4
# Norm: 15.49, NNZs: 12, Bias: -2.279489, T: 7877996, Avg. loss: 0.179138
# Total training time: 2.02 seconds.
# -- Epoch 5
# Norm: 15.31, NNZs: 12, Bias: -2.282535, T: 9847495, Avg. loss: 0.177589
# Total training time: 2.52 seconds.
# -- Epoch 6
# Norm: 15.33, NNZs: 12, Bias: -2.484265, T: 11816994, Avg. loss: 0.176724
# Total training time: 3.03 seconds.
# -- Epoch 7
# Norm: 15.13, NNZs: 12, Bias: -2.336351, T: 13786493, Avg. loss: 0.176067
# Total training time: 3.53 seconds.
# -- Epoch 8
# Norm: 15.06, NNZs: 12, Bias: -2.324932, T: 15755992, Avg. loss: 0.175624
# Total training time: 4.06 seconds.
# -- Epoch 9
# Norm: 15.08, NNZs: 12, Bias: -2.309430, T: 17725491, Avg. loss: 0.175265
# Total training time: 4.57 seconds.
# -- Epoch 10
# Norm: 15.01, NNZs: 12, Bias: -2.301388, T: 19694990, Avg. loss: 0.174991
# Total training time: 5.08 seconds.
# -- Epoch 11
# Norm: 14.91, NNZs: 12, Bias: -2.234621, T: 21664489, Avg. loss: 0.174769
# Total training time: 5.59 seconds.
# -- Epoch 12
# Norm: 14.94, NNZs: 12, Bias: -2.296928, T: 23633988, Avg. loss: 0.174565
# Total training time: 6.10 seconds.
# -- Epoch 13
# Norm: 14.88, NNZs: 12, Bias: -2.267100, T: 25603487, Avg. loss: 0.174427
# Total training time: 6.60 seconds.
# -- Epoch 14
# Norm: 14.89, NNZs: 12, Bias: -2.321252, T: 27572986, Avg. loss: 0.174299
# Total training time: 7.10 seconds.
# -- Epoch 15
# Norm: 14.90, NNZs: 12, Bias: -2.276721, T: 29542485, Avg. loss: 0.174159
# Total training time: 7.60 seconds.
# -- Epoch 16
# Norm: 14.89, NNZs: 12, Bias: -2.269221, T: 31511984, Avg. loss: 0.174087
# Total training time: 8.10 seconds.
# -- Epoch 17
# Norm: 14.85, NNZs: 12, Bias: -2.205824, T: 33481483, Avg. loss: 0.174030
# Total training time: 8.60 seconds.
# -- Epoch 18
# Norm: 14.86, NNZs: 12, Bias: -2.315651, T: 35450982, Avg. loss: 0.173892
# Total training time: 9.10 seconds.
# -- Epoch 19
# Norm: 14.84, NNZs: 12, Bias: -2.272310, T: 37420481, Avg. loss: 0.173811
# Total training time: 9.61 seconds.
# -- Epoch 20
# Norm: 14.85, NNZs: 12, Bias: -2.220498, T: 39389980, Avg. loss: 0.173804
# Total training time: 10.12 seconds.
# -- Epoch 21
# Norm: 14.85, NNZs: 12, Bias: -2.250856, T: 41359479, Avg. loss: 0.173744
# Total training time: 10.62 seconds.
# -- Epoch 22
# Norm: 14.85, NNZs: 12, Bias: -2.303765, T: 43328978, Avg. loss: 0.173689
# Total training time: 11.13 seconds.
# -- Epoch 23
# Norm: 14.82, NNZs: 12, Bias: -2.305693, T: 45298477, Avg. loss: 0.173634
# Total training time: 11.64 seconds.
# Convergence after 23 epochs took 11.64 seconds
# -- Epoch 1
# Norm: 14.85, NNZs: 12, Bias: -4.542832, T: 1969499, Avg. loss: 0.038482
# Total training time: 0.50 seconds.
# -- Epoch 2
# Norm: 12.64, NNZs: 12, Bias: -4.050839, T: 3938998, Avg. loss: 0.015801
# Total training time: 0.99 seconds.
# -- Epoch 3
# Norm: 11.94, NNZs: 12, Bias: -3.866228, T: 5908497, Avg. loss: 0.014952
# Total training time: 1.48 seconds.
# -- Epoch 4
# Norm: 11.52, NNZs: 12, Bias: -3.734795, T: 7877996, Avg. loss: 0.014621
# Total training time: 1.98 seconds.
# -- Epoch 5
# Norm: 11.33, NNZs: 12, Bias: -3.711760, T: 9847495, Avg. loss: 0.014482
# Total training time: 2.50 seconds.
# -- Epoch 6
# Norm: 11.22, NNZs: 12, Bias: -3.630640, T: 11816994, Avg. loss: 0.014359
# Total training time: 3.01 seconds.
# -- Epoch 7
# Norm: 11.15, NNZs: 12, Bias: -3.560102, T: 13786493, Avg. loss: 0.014276
# Total training time: 3.51 seconds.
# -- Epoch 8
# Norm: 11.05, NNZs: 12, Bias: -3.543375, T: 15755992, Avg. loss: 0.014212
# Total training time: 4.01 seconds.
# -- Epoch 9
# Norm: 11.02, NNZs: 12, Bias: -3.548630, T: 17725491, Avg. loss: 0.014175
# Total training time: 4.55 seconds.
# -- Epoch 10
# Norm: 10.95, NNZs: 12, Bias: -3.521188, T: 19694990, Avg. loss: 0.014163
# Total training time: 5.06 seconds.
# -- Epoch 11
# Norm: 10.91, NNZs: 12, Bias: -3.483981, T: 21664489, Avg. loss: 0.014114
# Total training time: 5.57 seconds.
# Convergence after 11 epochs took 5.57 seconds
# -- Epoch 1
# Norm: 11.86, NNZs: 12, Bias: -4.927322, T: 1969499, Avg. loss: 0.105717
# Total training time: 0.49 seconds.
# -- Epoch 2
# Norm: 11.47, NNZs: 12, Bias: -4.663681, T: 3938998, Avg. loss: 0.050070
# Total training time: 0.97 seconds.
# -- Epoch 3
# Norm: 11.35, NNZs: 12, Bias: -4.295318, T: 5908497, Avg. loss: 0.047625
# Total training time: 1.47 seconds.
# -- Epoch 4
# Norm: 11.22, NNZs: 12, Bias: -4.074669, T: 7877996, Avg. loss: 0.046595
# Total training time: 1.96 seconds.
# -- Epoch 5
# Norm: 11.23, NNZs: 12, Bias: -3.929677, T: 9847495, Avg. loss: 0.046087
# Total training time: 2.44 seconds.
# -- Epoch 6
# Norm: 11.25, NNZs: 12, Bias: -3.916565, T: 11816994, Avg. loss: 0.045712
# Total training time: 2.93 seconds.
# -- Epoch 7
# Norm: 11.24, NNZs: 12, Bias: -3.874527, T: 13786493, Avg. loss: 0.045473
# Total training time: 3.41 seconds.
# -- Epoch 8
# Norm: 11.38, NNZs: 12, Bias: -3.940630, T: 15755992, Avg. loss: 0.045303
# Total training time: 3.90 seconds.
# -- Epoch 9
# Norm: 11.34, NNZs: 12, Bias: -3.846476, T: 17725491, Avg. loss: 0.045140
# Total training time: 4.39 seconds.
# -- Epoch 10
# Norm: 11.33, NNZs: 12, Bias: -4.031828, T: 19694990, Avg. loss: 0.045050
# Total training time: 4.87 seconds.
# -- Epoch 11
# Norm: 11.30, NNZs: 12, Bias: -3.843442, T: 21664489, Avg. loss: 0.044953
# Total training time: 5.35 seconds.
# -- Epoch 12
# Norm: 11.33, NNZs: 12, Bias: -3.933042, T: 23633988, Avg. loss: 0.044883
# Total training time: 5.84 seconds.
# -- Epoch 13
# Norm: 11.31, NNZs: 12, Bias: -3.791625, T: 25603487, Avg. loss: 0.044814
# Total training time: 6.33 seconds.
# -- Epoch 14
# Norm: 11.36, NNZs: 12, Bias: -3.864878, T: 27572986, Avg. loss: 0.044763
# Total training time: 6.83 seconds.
# Convergence after 14 epochs took 6.83 seconds
# -- Epoch 1
# Norm: 20.35, NNZs: 12, Bias: -9.566220, T: 1969499, Avg. loss: 0.078194
# Total training time: 0.50 seconds.
# -- Epoch 2
# Norm: 18.22, NNZs: 12, Bias: -8.553685, T: 3938998, Avg. loss: 0.035340
# Total training time: 1.00 seconds.
# -- Epoch 3
# Norm: 17.37, NNZs: 12, Bias: -8.252513, T: 5908497, Avg. loss: 0.033647
# Total training time: 1.50 seconds.
# -- Epoch 4
# Norm: 17.14, NNZs: 12, Bias: -7.906984, T: 7877996, Avg. loss: 0.033023
# Total training time: 2.00 seconds.
# -- Epoch 5
# Norm: 16.91, NNZs: 12, Bias: -7.846755, T: 9847495, Avg. loss: 0.032629
# Total training time: 2.50 seconds.
# -- Epoch 6
# Norm: 16.72, NNZs: 12, Bias: -7.711377, T: 11816994, Avg. loss: 0.032460
# Total training time: 2.99 seconds.
# -- Epoch 7
# Norm: 16.61, NNZs: 12, Bias: -7.711518, T: 13786493, Avg. loss: 0.032314
# Total training time: 3.50 seconds.
# -- Epoch 8
# Norm: 16.59, NNZs: 12, Bias: -7.606054, T: 15755992, Avg. loss: 0.032149
# Total training time: 3.99 seconds.
# -- Epoch 9
# Norm: 16.48, NNZs: 12, Bias: -7.692079, T: 17725491, Avg. loss: 0.032096
# Total training time: 4.48 seconds.
# -- Epoch 10
# Norm: 16.43, NNZs: 12, Bias: -7.618297, T: 19694990, Avg. loss: 0.032025
# Total training time: 4.98 seconds.
# -- Epoch 11
# Norm: 16.40, NNZs: 12, Bias: -7.642539, T: 21664489, Avg. loss: 0.031984
# Total training time: 5.47 seconds.
# -- Epoch 12
# Norm: 16.39, NNZs: 12, Bias: -7.686764, T: 23633988, Avg. loss: 0.031920
# Total training time: 5.96 seconds.
# -- Epoch 13
# Norm: 16.34, NNZs: 12, Bias: -7.670164, T: 25603487, Avg. loss: 0.031878
# Total training time: 6.45 seconds.
# Convergence after 13 epochs took 6.45 seconds
# -- Epoch 1
# Norm: 32.20, NNZs: 12, Bias: -36.108538, T: 1969499, Avg. loss: 0.017131
# Total training time: 0.49 seconds.
# -- Epoch 2
# Norm: 22.86, NNZs: 12, Bias: -25.060493, T: 3938998, Avg. loss: 0.005502
# Total training time: 0.97 seconds.
# -- Epoch 3
# Norm: 18.73, NNZs: 12, Bias: -20.770782, T: 5908497, Avg. loss: 0.005096
# Total training time: 1.45 seconds.
# -- Epoch 4
# Norm: 16.55, NNZs: 12, Bias: -18.369633, T: 7877996, Avg. loss: 0.004977
# Total training time: 1.93 seconds.
# -- Epoch 5
# Norm: 15.01, NNZs: 12, Bias: -17.039877, T: 9847495, Avg. loss: 0.004967
# Total training time: 2.41 seconds.
# -- Epoch 6
# Norm: 14.10, NNZs: 12, Bias: -15.996529, T: 11816994, Avg. loss: 0.004964
# Total training time: 2.89 seconds.
# -- Epoch 7
# Norm: 13.42, NNZs: 12, Bias: -15.298492, T: 13786493, Avg. loss: 0.004960
# Total training time: 3.38 seconds.
# -- Epoch 8
# Norm: 12.92, NNZs: 12, Bias: -14.784731, T: 15755992, Avg. loss: 0.004971
# Total training time: 3.89 seconds.
# -- Epoch 9
# Norm: 12.55, NNZs: 12, Bias: -14.381664, T: 17725491, Avg. loss: 0.004979
# Total training time: 4.37 seconds.
# Convergence after 9 epochs took 4.37 seconds
# ✅Trainings-Score: 0.9097
# ✅Trainings-Score: 0.9097
# 📋 Klassifikationsbericht gespeichert.
# 📊 Confusion Matrix gespeichert.
# ✅ Training abgeschlossen und alles gespeichert.
# ⏱️ Laufzeit: 00:01:13.69 (Std:Min:Sek)

# %% [markdown]
# ## Teil 2: Anwendung auf neue Punktwolke

# %%
start_time = time.time()

result_dir = "Resultate_SGDClassifier_v3"
# 1. Modell und Scaler laden
model = joblib.load(os.path.join(result_dir, "sgd_model.pkl"))
scaler = joblib.load(os.path.join(result_dir, "scaler.pkl"))
with open(os.path.join(result_dir, "label_mapping.pkl"), "rb") as f:
    label_mapping = pickle.load(f)

# 2. Neue Punktwolke laden
input_file = Path("PW_P3A2_normalisiert.txt")
df = pd.read_csv(input_file, sep=";", header=None)

# 3. Dateiname auslesen
file_name = input_file.stem
parts = file_name.split("_")
objekt, klass = parts[0], parts[1] if len(parts) >= 2 else ("Unknown", "Unknown")
parts2 = result_dir.split("_")
classifier, model_name = parts2[-2], parts2[-1] 
file_name_neu = f"{objekt}_{klass}_{classifier}_{model_name}"

# 4. Spaltennamen definieren (ohne Label!)
df.columns = [
    "X", "Y", "Z",
    "Red", "Green", "Blue",
    "Hue", "Saturation", "Value",
    "X_dir", "Y_dir", "Z_dir"
]

# 5. Feature-Auswahl
X_new = df[[
    "X", "Y", "Z",
    "Red", "Green", "Blue",
    "Hue", "Saturation", "Value",
    "X_dir", "Y_dir", "Z_dir"
]]

# 6. Skalieren & Klassifizieren
X_new_scaled = scaler.transform(X_new)
predicted_labels = model.predict(X_new_scaled)
df["Predicted_Label"] = predicted_labels
df["Label_Decoded"] = pd.Series(predicted_labels).map(label_mapping)

# 7. Speichern
# 7.1 Gesamte Punktwolke mit Vorhersage als TXT
output_txt = os.path.join(result_dir, f"{file_name_neu}.txt")
df.to_csv(output_txt, sep=";", index=False)
print(f"✅ Punktwolke mit Vorhersage gespeichert als {output_txt}")

# 7.2 Punktwolke nach Klassen aufteilen und speichern
for label_value, gruppe in df.groupby("Label_Decoded"):
    klass_datei = os.path.join(result_dir, f"{file_name_neu}_{label_value}.txt")
    gruppe.to_csv(klass_datei, sep=";", index=False)
    print(f"✅ Klasse '{label_value}' gespeichert als {klass_datei}")

# 8. Zeit anzeigen
elapsed = time.time() - start_time
h, rem = divmod(elapsed, 3600)
m, s = divmod(rem, 60)
print(f"⏱️ Laufzeit: {int(h):02d}:{int(m):02d}:{s:05.2f} (Std:Min:Sek)")
# Out:
# ✅ Punktwolke mit Vorhersage gespeichert als Resultate_SGDClassifier_v3\PW_P3A2_SGDClassifier_v3.txt
# ✅ Klasse 'Bäume' gespeichert als Resultate_SGDClassifier_v3\PW_P3A2_SGDClassifier_v3_Bäume.txt
# ✅ Klasse 'Fassade' gespeichert als Resultate_SGDClassifier_v3\PW_P3A2_SGDClassifier_v3_Fassade.txt
# ✅ Klasse 'Flachdach' gespeichert als Resultate_SGDClassifier_v3\PW_P3A2_SGDClassifier_v3_Flachdach.txt
# ✅ Klasse 'Ground' gespeichert als Resultate_SGDClassifier_v3\PW_P3A2_SGDClassifier_v3_Ground.txt
# ✅ Klasse 'Schrägdach' gespeichert als Resultate_SGDClassifier_v3\PW_P3A2_SGDClassifier_v3_Schrägdach.txt
# ✅ Klasse 'Strasse' gespeichert als Resultate_SGDClassifier_v3\PW_P3A2_SGDClassifier_v3_Strasse.txt
# ✅ Klasse 'Trottoir' gespeichert als Resultate_SGDClassifier_v3\PW_P3A2_SGDClassifier_v3_Trottoir.txt
# ✅ Klasse 'Wasser' gespeichert als Resultate_SGDClassifier_v3\PW_P3A2_SGDClassifier_v3_Wasser.txt
# ⏱️ Laufzeit: 00:01:07.82 (Std:Min:Sek)
